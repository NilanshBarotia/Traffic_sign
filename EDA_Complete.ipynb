# %%
import torch
import pandas as pd
import numpy as np
from pathlib import Path
from fastai.vision.all import *

# %%
path = Path('D:\Traffic')

# %%
path1 = path/'traffic_Data'/'DATA'
path2 = path/'labels.csv'

# %%
len((path1/'0').ls())
# Out:
# 118

# %%
for x in range(58):
    print(f'{x} :-', end = ' ')
    print(len((path1/f'{x}').ls()))
# Out:
# 0 :- 118
# 1 :- 40
# 2 :- 80
# 3 :- 260
# 4 :- 98
# 5 :- 194
# 6 :- 78
# 7 :- 152
# 8 :- 8
# 9 :- 2
# 10 :- 70
# 11 :- 138
# 12 :- 96
# 13 :- 36
# 14 :- 128
# 15 :- 22
# 16 :- 142
# 17 :- 130
# 18 :- 8
# 19 :- 4
# 20 :- 18
# 21 :- 12
# 22 :- 18
# 23 :- 14
# 24 :- 100
# 25 :- 2
# 26 :- 126
# 27 :- 28
# 28 :- 446
# 29 :- 44
# 30 :- 150
# 31 :- 42
# 32 :- 14
# 33 :- 4
# 34 :- 26
# 35 :- 156
# 36 :- 40
# 37 :- 58
# 38 :- 30
# 39 :- 34
# 40 :- 32
# 41 :- 18
# 42 :- 32
# 43 :- 82
# 44 :- 30
# 45 :- 24
# 46 :- 18
# 47 :- 12
# 48 :- 10
# 49 :- 42
# 50 :- 56
# 51 :- 8
# 52 :- 36
# 53 :- 2
# 54 :- 324
# 55 :- 162
# 56 :- 110
# 57 :- 6
