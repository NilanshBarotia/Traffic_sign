# %% [markdown]
# This file will be for deciding weight decay

# %% [markdown]
# From previous files, the lr for head is 0.0017378008365631102 and lr range for whole model is ((1.9054607491852948e-06)/10, (1.9054607491852948e-06)/4)
# The no. of epochs for head remains const. at 3 and no. of epochs for whole model is 8 as found in prev. file
# The batch size found is 16 from prev. file

# %% [markdown]
# I will vary wd value from 0 to 1e-2

# %%
import pandas as pd
import regex as re
from fastai.vision.all import *

# %%
df = pd.read_csv(r'D:\Traffic\labels_processed.csv')

# %%
def label_function(dpath):
    class_name = re.findall(r'(\d+)_.*\.png$', dpath.name)
    class_id = int(class_name[0])
    return df['Names'][class_id]

# %%
signs = DataBlock(blocks = (ImageBlock, CategoryBlock),
                  get_items = get_image_files,
                  splitter = RandomSplitter(seed = 42),
                  get_y = label_function,
                  item_tfms = Resize(224),
                  batch_tfms = aug_transforms(size = 224, min_scale = 0.75, do_flip = False))

# %%
path = Path(r'D:\Traffic\traffic_Data_processed\DATA')

# %%
lr_head = 0.0017378008365631102
lr_whole_model = 1.9054607491852948e-06

# %%
set_seed(42, reproducible = True)

# %%
dls_4_1 = signs.dataloaders(path, bs = 16)

# %%
model_4_1 = vision_learner(dls_4_1, arch = resnet34, metrics = error_rate)
model_4_1.fit_one_cycle(3, lr_head, wd = 0)
model_4_1.unfreeze()
model_4_1.fit_one_cycle(8, lr_max = slice(lr_whole_model/10, lr_whole_model/4), wd = 0)
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
# ...

# %%
set_seed(42, reproducible = True)

# %%
dls_4_2 = signs.dataloaders(path, bs = 16)

# %%
model_4_2 = vision_learner(dls_4_2, arch = resnet34, metrics = error_rate)
model_4_2.fit_one_cycle(3, lr_head, wd = 1e-5)
model_4_2.unfreeze()
model_4_2.fit_one_cycle(8, lr_max = slice(lr_whole_model/10, lr_whole_model/4), wd = 1e-5)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.916897</td><td>0.188041</td><td>0.048193</td><td>00:26</td></tr><tr><td>1</td><td>0.214843</td><td>0.042885</td><td>0.020482</td><td>00:25</td></tr><tr><td>2</td><td>0.097780</td><td>0.031382</td><td>0.009639</td><td>00:25</td></tr></tbody></table></div>
# ...

# %%
set_seed(42, reproducible = True)

# %%
dls_4_3 = signs.dataloaders(path, bs = 16)

# %%
model_4_3 = vision_learner(dls_4_3, arch = resnet34, metrics = error_rate)
model_4_3.fit_one_cycle(3, lr_head, wd = 1e-4)
model_4_3.unfreeze()
model_4_3.fit_one_cycle(8, lr_max = slice(lr_whole_model/10, lr_whole_model/4), wd = 1e-4)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.917335</td><td>0.182722</td><td>0.045783</td><td>00:35</td></tr><tr><td>1</td><td>0.212272</td><td>0.064721</td><td>0.024096</td><td>00:35</td></tr><tr><td>2</td><td>0.103402</td><td>0.033672</td><td>0.010843</td><td>00:36</td></tr></tbody></table></div>
# ...

# %%
set_seed(42, reproducible = True)

# %%
dls_4_4 = signs.dataloaders(path, bs = 16)

# %%
model_4_4 = vision_learner(dls_4_4, arch = resnet34, metrics = error_rate)
model_4_4.fit_one_cycle(3, lr_head, wd = 1e-3)
model_4_4.unfreeze()
model_4_4.fit_one_cycle(8, lr_max = slice(lr_whole_model/10, lr_whole_model/4), wd = 1e-3)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.921564</td><td>0.201345</td><td>0.049398</td><td>00:34</td></tr><tr><td>1</td><td>0.223698</td><td>0.051779</td><td>0.015663</td><td>00:32</td></tr><tr><td>2</td><td>0.111830</td><td>0.034627</td><td>0.009639</td><td>00:22</td></tr></tbody></table></div>
# ...

# %%
set_seed(42, reproducible = True)

# %%
dls_4_5 = signs.dataloaders(path, bs = 16)

# %%
model_4_5 = vision_learner(dls_4_5, arch = resnet34, metrics = error_rate)
model_4_5.fit_one_cycle(3, lr_head, wd = 1e-2)
model_4_5.unfreeze()
model_4_5.fit_one_cycle(8, lr_max = slice(lr_whole_model/10, lr_whole_model/4), wd = 1e-2)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.921047</td><td>0.198062</td><td>0.053012</td><td>00:28</td></tr><tr><td>1</td><td>0.202217</td><td>0.061283</td><td>0.015663</td><td>00:25</td></tr><tr><td>2</td><td>0.097367</td><td>0.032212</td><td>0.010843</td><td>00:25</td></tr></tbody></table></div>
# ...

# %% [markdown]
# Both wd 1e-3 and 1e-2 are good but prefer 1e-3 as samller changes are preffered
